# %% [markdown]
# <a href="https://colab.research.google.com/github/nourelfaramawy/MERN-Stack-Tutorial/blob/main/DPGANs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/CKZfd/DPGANs
# Out:
# Cloning into 'DPGANs'...
# remote: Enumerating objects: 122, done.
# remote: Total 122 (delta 0), reused 0 (delta 0), pack-reused 122
# Receiving objects: 100% (122/122), 3.51 MiB | 20.29 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# %cd DPGANs
# Out:
# /content/DPGANs

# %%
# %cd paired-dataset
# Out:
# /content/DPGANs/paired-dataset

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd ..
# Out:
# /content/DPGANs

# %%
# !python training_data.py

# %%
# !python testing_data.py

# %%
# !cp -r DPGANs '/content/drive/My Drive/Git DPGAN'
# Out:
# cp: cannot stat 'DPGANs': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python main_DPGANs.py --dataroot ./facades/rainydataset/training --valDataroot ./facades/rainydataset/val
# Out:
# Namespace(dataset='pix2pix', dataroot='./facades/rainydataset/training', valDataroot='./facades/rainydataset/val', mode='B2A', batchSize=7, valBatchSize=14, originalSize=286, imageSize=256, inputChannelSize=3, outputChannelSize=3, ngf=64, ndf=64, niter=200, lrD=0.0002, lrG=0.0002, annealStart=0, annealEvery=200, lambdaL1=25.0, lambdaGAN=1.0, lambdaP1=5.0, lambdaP2=1.5, lambdaP3=1.5, lambdaP4=1, poolSize=50, wd=0.0, beta1=0.5, netG='', netD='', workers=2, exp='check', display=5, evalIter=200, saveIter=5, pretrained_model=None, Perceptual=1, margin=0.5)
# Random Seed:  7418
# /content/DPGANs/transforms/pix2pix.py:41: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
# ...
